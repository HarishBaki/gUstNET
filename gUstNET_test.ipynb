# %%
# first thing we do is to set the environment variable CUDA_VISIBLE_DEVICES to the GPU we want to use
import os
#Only CPUs
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Specify the GPUs to use
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2"
nGPUs = len(os.environ["CUDA_VISIBLE_DEVICES"].split(','))
print('Using GPUs:', os.environ["CUDA_VISIBLE_DEVICES"], 'Total:', nGPUs)
# Out:
# Using GPUs: 0,1,2 Total: 3

# %%
import xarray as xr
import numpy as np
import zarr
import os, sys, time, glob, re

import tensorflow as tf
print(tf.version)
from tensorflow import keras
print(keras.__version__)

from keras import layers
from keras.layers import Layer
from keras import models, losses
from keras.regularizers import l1,l2
from keras.optimizers import Optimizer, Adam
from keras.callbacks import EarlyStopping
strategy = tf.distribute.MirroredStrategy()
# Set the logging level to suppress warnings
tf.get_logger().setLevel(tf.compat.v1.logging.ERROR)

# set the directory to current directory
root_dir = '/data/harish/'

sys.path.append(root_dir)
from libraries import *
# Out:
# 2024-09-22 14:23:57.729010: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-22 14:23:57.740610: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-22 14:23:57.744378: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-22 14:23:57.753749: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <module 'tensorflow._api.v2.version' from '/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/tensorflow/_api/v2/version/__init__.py'>
# 3.5.0
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727029438.941665  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029438.941981  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029438.942294  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029438.989717  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029438.990052  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029438.990304  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029438.990554  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029438.990794  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029438.991028  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.254878  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.255166  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.255403  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.255649  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.255878  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.256101  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.256320  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.256546  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.256767  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.273563  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.274030  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.274285  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.274534  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.274772  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.275174  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1727029439.275479  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-22 14:23:59.275835: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46857 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0000 00:00:1727029439.276303  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-22 14:23:59.276517: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46857 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# I0000 00:00:1727029439.276833  176396 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-22 14:23:59.277048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46098 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6
# <module 'tensorflow._api.v2.version' from '/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/tensorflow/_api/v2/version/__init__.py'>
# 3.5.0

# %%
# Checking if the GPU is available and if it is being used
def run_on_gpu(device_index):
    device_name = f'/device:GPU:{device_index}'
    with tf.device(device_name):
        a = tf.random.uniform([2, 2])
        b = tf.random.uniform([2, 2])
        c = tf.matmul(a, b)
        print(f"Running on {device_name}:")
        print(c.numpy())

# List available GPUs
gpus = tf.config.list_physical_devices('GPU')

# Run the function for each GPU
for i, gpu in enumerate(gpus):
    run_on_gpu(i)
# Out:
# Running on /device:GPU:0:
# [[0.8024075  0.74058527]
#  [0.79024094 0.72814053]]
# Running on /device:GPU:1:
# [[0.35040656 0.26347527]
#  [0.5287429  0.41112804]]
# Running on /device:GPU:2:
# [[0.91092753 0.7168515 ]
#  [1.219977   0.8869949 ]]

# %% [markdown]
# # Defining architecture and necessary functions

# %%
#----------------------------------------------------------------
# Build base U-net architecture
#----------------------------------------------------------------

def actv_switch(switch, negative_slope):
    '''
    Non-linear Activation switch - 0: linear; 1: non-linear
    If non-linear, then Leaky ReLU Activation function with negative_slope value as input
    '''
    if switch == 0:
        actv = "linear"
    else:
        actv = layers.LeakyReLU(negative_slope=negative_slope)
    return actv

class ReflectPadding2D(Layer):
    '''
    Reflection padding mode. 
    In reflection padding, the padded values are a reflection of the edge values of the input tensor. 
    For example, if the input is [1, 2, 3], reflection padding would give [2, 1, 1, 2, 3, 2].
    This padding is necessary when the filter size is beyond 3. 
    Since the input tensor is convolved with the filter, the filter goes out of bounds of the input tensor at the edges.
    Typically, it will increase the input tensor size by 2*pad_size in each dimension. 
    But after convolution, the output tensor size will be the same as the initial input tensor size.
    '''
    def __init__(self, pad_size, **kwargs):
        self.pad_size = pad_size
        super(ReflectPadding2D, self).__init__(**kwargs)

    def call(self, inputs):
        return tf.pad(inputs, [[0, 0], [self.pad_size, self.pad_size], [self.pad_size, self.pad_size], [0, 0]], mode='REFLECT')

    def get_config(self):
        config = super(ReflectPadding2D, self).get_config()
        config.update({"pad_size": self.pad_size})
        return config
    
def con2d(input, out_channels, filter, dilation_rate, stride, switch, negative_slope, regularize_value):
    '''
    input: input tensor
    out_channels: number of output feature maps
    filter: filter size
    dilation_rate: dilation rate
    stride: stride
    switch: activation switch
    negative_slope: negative slope for Leaky ReLU
    regularize_value: regularizer factor
    '''
    # Manually apply reflect padding
    pad_size = filter // 2
    # Use ReflectPadding2D instead of custom padding directly
    inp_padded = ReflectPadding2D(pad_size)(input)
    # Apply the convolutional layer with 'valid' padding since we've already padded the input
    return layers.Conv2D(out_channels, (filter, filter), dilation_rate=(dilation_rate, dilation_rate),
                                  strides=stride,
                                  activation=actv_switch(switch, negative_slope),
                                  padding="valid", #padding="same",
                                  use_bias=True,
                                  kernel_regularizer=l2(regularize_value),
                                  bias_regularizer=l2(regularize_value))(inp_padded)

# Residual convolution block
def Res_conv_block(input, out_channels, filter, dilation_rate, stride, switch, negative_slope, regularize_value):
    '''
    input: input tensor
    out_channels: number of output feature maps
    filter: filter size
    dilation_rate: dilation rate
    stride: stride
    switch: activation switch
    negative_slope: negative slope for Leaky ReLU
    regularize_value: regularizer factor
    '''
    y = con2d(input, out_channels, filter, dilation_rate, stride, switch, negative_slope, regularize_value)
    y = con2d(input, out_channels, filter, dilation_rate, stride, switch, negative_slope, regularize_value)
    # Residual connection
    y = layers.Add()([y, con2d(input, out_channels, 1, dilation_rate, stride, switch, negative_slope, regularize_value)])

    return y

# Convolution downsampling block
def Conv_down_block(input, out_channels, filter, dilation_rate, stride, switch, negative_slope, regularize_value):

    # Downsampling using the stride 2
    y = con2d(input, out_channels, filter, dilation_rate, 2, switch, negative_slope, regularize_value)
    y = con2d(y, out_channels, filter, dilation_rate, stride, switch, negative_slope, regularize_value)
    y = con2d(y, out_channels, filter, dilation_rate, stride, switch, negative_slope, regularize_value)

    return y

# Attention block
def Attention(input, num_heads, key_dim):

    layer = layers.MultiHeadAttention(num_heads, key_dim, attention_axes=None)
    y = layer(input, input)

    return y

# Convolution upsampling block using bilinear interpolation
def Conv_up_block(input, out_channels, filter, dilation_rate, stride, switch, negative_slope, regularize_value):

    # Upsampling using the stride 2 with transpose convolution
    y = layers.UpSampling2D(size=(2, 2), interpolation='bilinear')(input)
    y = con2d(y, out_channels, filter, dilation_rate, stride, switch, negative_slope, regularize_value)
    y = con2d(y, out_channels, filter, dilation_rate, stride, switch, negative_slope, regularize_value)

    return y

#2D Pooling layer - inputs[0:avg;1:max, input tensor, pool size]
def pool2d(i, input, pool_size):
    if i == 0:
        return layers.AveragePooling2D(pool_size=(pool_size, pool_size),
                                            strides=None,
                                            padding='same',
                                            data_format=None)(input)
    else:
        return layers.MaxPooling2D(pool_size=(pool_size, pool_size),
                                            strides=None,
                                            padding='same',
                                            data_format=None)(input)


# Generator architecture
def Gen(inp_lat, inp_lon, out_lat, out_lon, chnl, out_vars, filter, dilation_rate, stride, switch, negative_slope, regulazier_value, num_heads, key_dim):
    '''
    inp_lat: input latitude
    inp_lon: input longitude
    out_lat: output latitude
    out_lon: output longitude
    chnl: number of input channels
    out_vars: number of output variables
    filter: filter size
    dilation_rate: dilation rate
    stride: stride
    switch: activation switch
    negative_slope: negative slope for Leaky ReLU
    regulazier_value: regularizer factor
    num_heads: number of attention heads
    key_dim: key dimension
    '''

    input = layers.Input(shape=(inp_lat, inp_lon, chnl))
    #y_static = layers.Input(shape=(out_lat, out_lon, 1))

    #y = layers.Concatenate(axis=-1)([input, y_static])

    y = input

    # Encoding path
    skips = []
    for n_out in [64, 128, 256]:
        y = Res_conv_block(y, n_out, filter, dilation_rate, stride, switch, negative_slope, regulazier_value)
        skips.append(Res_conv_block(y, n_out // 4, filter, dilation_rate, stride, switch, negative_slope, regulazier_value))
        y = Conv_down_block(y, n_out, filter, dilation_rate, stride, switch, negative_slope, regulazier_value)

    # Attention block
    y = Res_conv_block(y, 256, filter, dilation_rate, stride, switch, negative_slope, regulazier_value)
    y = Attention(y, num_heads, key_dim)
    y = Res_conv_block(y, 256, filter, dilation_rate, stride, switch, negative_slope, regulazier_value)
    y = Attention(y, num_heads, key_dim)
    y = Res_conv_block(y, 256, filter, dilation_rate, stride, switch, negative_slope, regulazier_value)

    # Decoding path
    for i, n_out in enumerate([256, 128, 64]):
        y = Conv_up_block(y, n_out, filter, dilation_rate, stride, switch, negative_slope, regulazier_value)
        y = layers.Concatenate(axis=-1)([y, skips[-(i + 1)]])
        y = Res_conv_block(y, n_out, filter, dilation_rate, stride, switch, negative_slope, regulazier_value)

    y = Res_conv_block(y, 32, filter, dilation_rate, stride, switch, negative_slope, regulazier_value)

    y = con2d(y, 32, 1, dilation_rate, stride, 0, 0, regulazier_value)
    y = con2d(y, out_vars, 1, dilation_rate, stride, 0, 0, regulazier_value)

    #return models.Model(inputs=[input,y_static], outputs=y)
    return models.Model(inputs=input, outputs=y)

# %% [markdown]
# # Loading data

# %%
zarr_path = f'{root_dir}/rtma_i10fg_NYS_subset.zarr'
train_val_dates_range = ('2021-01-01T00', '2022-12-31T23')
# Define input/output window sizes
in_times = 3   # Example: 24 input hours (1 day)
out_times = 1   # Example: 6 output hours (6-hour prediction)

X_train_times, Y_train_times, X_val_times, Y_val_times = RTMA_data_splitting(zarr_path,train_val_dates_range,in_times,out_times,opt_test=False)

# %%
test_dates_range = ('2023-01-01T00', '2023-12-31T23')

X_test_times, Y_test_times = RTMA_data_splitting(zarr_path,test_dates_range,in_times,out_times,opt_test=True)

# %%
len(X_train_times)%(32*3)
# Out:
# 18

# %%
ds = xr.open_zarr(zarr_path)
data = ds.i10fg#.transpose(..., 'time')
X_train = data.sel(time=X_train_times).transpose('sample', 'y', 'x','time_window')
Y_train = data.sel(time=Y_train_times).transpose('sample', 'y', 'x','time_window')
# To fit the samples equally into the GPUs and batches, we need to exclude the remaining bathces
X_train = X_train[:-int(len(X_train)%(32*3)),...]
Y_train = Y_train[:-int(len(Y_train)%(32*3)),...]
X_val = data.sel(time=X_val_times).transpose('sample', 'y', 'x','time_window')
Y_val = data.sel(time=Y_val_times).transpose('sample', 'y', 'x','time_window')
X_test = data.sel(time=X_test_times).transpose('sample', 'y', 'x','time_window')
Y_test = data.sel(time=Y_test_times).transpose('sample', 'y', 'x','time_window')

print('X_train',X_train.shape, 'Y_train',Y_train.shape, 
      'X_val',X_val.shape, 'Y_val',Y_val.shape, 
      'X_test',X_test.shape, 'Y_test',Y_test.shape)
# Out:
# X_train (14016, 256, 384, 3) Y_train (14016, 256, 384, 1) X_val (3456, 256, 384, 3) Y_val (3456, 256, 384, 1) X_test (8757, 256, 384, 3) Y_test (8757, 256, 384, 1)

# %%
X_train[:32*3,...]
# Out:
# <xarray.DataArray 'i10fg' (sample: 96, y: 256, x: 384, time_window: 3)>
# dask.array<getitem, shape=(96, 256, 384, 3), dtype=float32, chunksize=(96, 256, 384, 3), chunktype=numpy.ndarray>
# Coordinates:
#     heightAboveGround  float64 ...
#     latitude           (y, x) float64 dask.array<chunksize=(256, 384), meta=np.ndarray>
#     longitude          (y, x) float64 dask.array<chunksize=(256, 384), meta=np.ndarray>
#     step               timedelta64[ns] ...
#     time               (sample, time_window) datetime64[ns] 2021-01-01 ... 20...
#     valid_time         (sample, time_window) datetime64[ns] dask.array<chunksize=(96, 3), meta=np.ndarray>
# Dimensions without coordinates: sample, y, x, time_window
# Attributes: (12/34)
#     GRIB_DxInMetres:                          2539.703
#     GRIB_DyInMetres:                          2539.703
#     GRIB_LaDInDegrees:                        25.0
#     GRIB_Latin1InDegrees:                     25.0
#     GRIB_Latin2InDegrees:                     25.0
#     GRIB_LoVInDegrees:                        265.0
#     ...                                       ...
#     GRIB_typeOfLevel:                         heightAboveGround
#     GRIB_units:                               m s**-1
#     GRIB_uvRelativeToGrid:                    1
#     long_name:                                Instantaneous 10 metre wind gust
#     standard_name:                            unknown
#     units:                                    m s**-1

# %% [markdown]
# # Initialize a model

# %%
# -------------------------------------------------------------------------
# Model initialising and summary print 
# -------------------------------------------------------------------------
# Build the generator model
generator = Gen(X_train.shape[1], X_train.shape[2], Y_train.shape[1], Y_train.shape[2], 
                  X_train.shape[3], Y_train.shape[3], 5, 1, 1, 1, 0.2, 0, 1, 64)
print(generator.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 384,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_1 │ (None, 260, 388,  │          0 │ input_layer[0][0] │
# │ (ReflectPadding2D)  │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_2 │ (None, 256, 384,  │          0 │ input_layer[0][0] │
# │ (ReflectPadding2D)  │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 384,  │      4,864 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 384,  │        256 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 256, 384,  │          0 │ conv2d_1[0][0],   │
# │                     │ 64)               │            │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_6 │ (None, 260, 388,  │          0 │ add[0][0]         │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 128, 192,  │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_7 │ (None, 132, 196,  │          0 │ conv2d_6[0][0]    │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 128, 192,  │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_8 │ (None, 132, 196,  │          0 │ conv2d_7[0][0]    │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 128, 192,  │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ conv2d_8[0][0]    │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 128, 192,  │          0 │ conv2d_8[0][0]    │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 192,  │    204,928 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 192,  │      8,320 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 128, 192,  │          0 │ conv2d_10[0][0],  │
# │                     │ 128)              │            │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ add_2[0][0]       │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 96,    │    409,728 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_15[0][0]   │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 64, 96,    │    409,728 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_16[0][0]   │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 64, 96,    │    409,728 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_17[0][0]   │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 64, 96,    │          0 │ conv2d_17[0][0]   │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 64, 96,    │    819,456 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 64, 96,    │     33,024 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 64, 96,    │          0 │ conv2d_19[0][0],  │
# │                     │ 256)              │            │ conv2d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ add_4[0][0]       │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ conv2d_24[0][0]   │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ conv2d_25[0][0]   │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ conv2d_26[0][0]   │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 32, 48,    │          0 │ conv2d_26[0][0]   │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 32, 48,    │     65,792 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 32, 48,    │          0 │ conv2d_28[0][0],  │
# │                     │ 256)              │            │ conv2d_29[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 32, 48,    │     65,984 │ add_6[0][0],      │
# │ (MultiHeadAttentio… │ 256)              │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ multi_head_atten… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 32, 48,    │          0 │ multi_head_atten… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 32, 48,    │     65,792 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 32, 48,    │          0 │ conv2d_31[0][0],  │
# │                     │ 256)              │            │ conv2d_32[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 32, 48,    │     65,984 │ add_7[0][0],      │
# │ (MultiHeadAttentio… │ 256)              │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ multi_head_atten… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 32, 48,    │          0 │ multi_head_atten… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 32, 48,    │     65,792 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 32, 48,    │          0 │ conv2d_34[0][0],  │
# │                     │ 256)              │            │ conv2d_35[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 64, 96,    │          0 │ add_8[0][0]       │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ up_sampling2d[0]… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 64, 96,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ add_4[0][0]       │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 64, 96,    │          0 │ add_4[0][0]       │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_36[0][0]   │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 64, 96,    │    409,664 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 64, 96,    │     16,448 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 64, 96,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 64, 96,    │          0 │ conv2d_22[0][0],  │
# │                     │ 64)               │            │ conv2d_23[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 96,    │          0 │ conv2d_37[0][0],  │
# │ (Concatenate)       │ 320)              │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ concatenate[0][0] │
# │ (ReflectPadding2D)  │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 64, 96,    │          0 │ concatenate[0][0] │
# │ (ReflectPadding2D)  │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 64, 96,    │  2,048,256 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 64, 96,    │     82,176 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 64, 96,    │          0 │ conv2d_39[0][0],  │
# │                     │ 256)              │            │ conv2d_40[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 128, 192,  │          0 │ add_9[0][0]       │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ up_sampling2d_1[… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 128, 192,  │    819,328 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ add_2[0][0]       │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 128, 192,  │          0 │ add_2[0][0]       │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ conv2d_41[0][0]   │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 192,  │    102,432 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 192,  │      4,128 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 128, 192,  │    409,728 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 128, 192,  │          0 │ conv2d_13[0][0],  │
# │                     │ 32)               │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 192,  │          0 │ conv2d_42[0][0],  │
# │ (Concatenate)       │ 160)              │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ concatenate_1[0]… │
# │ (ReflectPadding2D)  │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 128, 192,  │          0 │ concatenate_1[0]… │
# │ (ReflectPadding2D)  │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 128, 192,  │    512,128 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 128, 192,  │     20,608 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 128, 192,  │          0 │ conv2d_44[0][0],  │
# │                     │ 128)              │            │ conv2d_45[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 256, 384,  │          0 │ add_10[0][0]      │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ up_sampling2d_2[… │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 256, 384,  │    204,864 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_4 │ (None, 260, 388,  │          0 │ add[0][0]         │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_5 │ (None, 256, 384,  │          0 │ add[0][0]         │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ conv2d_46[0][0]   │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 256, 384,  │     25,616 │ reflect_padding2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 256, 384,  │      1,040 │ reflect_padding2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 256, 384,  │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 256, 384,  │          0 │ conv2d_4[0][0],   │
# │                     │ 16)               │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 384,  │          0 │ conv2d_47[0][0],  │
# │ (Concatenate)       │ 80)               │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ concatenate_2[0]… │
# │ (ReflectPadding2D)  │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 256, 384,  │          0 │ concatenate_2[0]… │
# │ (ReflectPadding2D)  │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 256, 384,  │    128,064 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 256, 384,  │      5,184 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 256, 384,  │          0 │ conv2d_49[0][0],  │
# │                     │ 64)               │            │ conv2d_50[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ add_11[0][0]      │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 256, 384,  │          0 │ add_11[0][0]      │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 256, 384,  │     51,232 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 256, 384,  │      2,080 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 256, 384,  │          0 │ conv2d_52[0][0],  │
# │                     │ 32)               │            │ conv2d_53[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 256, 384,  │          0 │ add_12[0][0]      │
# │ (ReflectPadding2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 256, 384,  │      1,056 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 256, 384,  │          0 │ conv2d_54[0][0]   │
# │ (ReflectPadding2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 256, 384,  │         33 │ reflect_padding2… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,992,545 (80.08 MB)
#  Trainable params: 20,992,545 (80.08 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
#----------------------------------------------------------------
# Defining loss functions
#----------------------------------------------------------------
MAE = tf.keras.losses.MeanAbsoluteError()
MSE = tf.keras.losses.MeanSquaredError()

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

generator.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss=MAE,
    metrics=[MSE, MAE]
)

# %%
# Now train the model using the shuffled data
generator.fit(
    X_train,
    Y_train,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping],
    validation_data=(X_val, Y_val)
)
# Out:
# Epoch 1/100
# I0000 00:00:1727011268.379322  111276 service.cc:146] XLA service 0x7ed08021cb20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727011268.379351  111276 service.cc:154]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# I0000 00:00:1727011268.379354  111276 service.cc:154]   StreamExecutor device (1): NVIDIA RTX A6000, Compute Capability 8.6
# I0000 00:00:1727011268.379356  111276 service.cc:154]   StreamExecutor device (2): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-09-22 09:21:08.806149: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-22 09:21:09.694947: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90201
# 2024-09-22 09:21:11.209922: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_27', 8 bytes spill stores, 8 bytes spill loads
#
# 2024-09-22 09:21:11.502050: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_49', 4 bytes spill stores, 4 bytes spill loads
#
# 2024-09-22 09:21:11.538004: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_18', 304 bytes spill stores, 436 bytes spill loads
#
# 2024-09-22 09:21:11.553676: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_51', 60 bytes spill stores, 60 bytes spill loads
#
# 2024-09-22 09:21:11.572439: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_51', 360 bytes spill stores, 360 bytes spill loads
#
# 2024-09-22 09:21:11.619467: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_50', 36 bytes spill stores, 36 bytes spill loads
#
# 2024-09-22 09:21:11.676803: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_51', 2684 bytes spill stores, 2668 bytes spill loads
#
# 2024-09-22 09:21:11.681433: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_51', 8 bytes spill stores, 8 bytes spill loads
#
# 2024-09-22 09:21:11.738174: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_51', 664 bytes spill stores, 664 bytes spill loads
#
# 2024-09-22 09:21:11.755957: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot', 316 bytes spill stores, 436 bytes spill loads
#
# 2024-09-22 09:21:12.002648: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_46', 72 bytes spill stores, 72 bytes spill loads
#
# 2024-09-22 09:21:50.849697: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,80,260,388]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,384]{3,2,1,0}, f32[64,80,5,5]{3,2,1,0}), window={size=5x5}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-09-22 09:21:52.302663: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.453089629s
# Trying algorithm eng0{} for conv (f32[32,80,260,388]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,384]{3,2,1,0}, f32[64,80,5,5]{3,2,1,0}), window={size=5x5}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-09-22 09:21:58.422849: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,64,260,388]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,384]{3,2,1,0}, f32[64,64,5,5]{3,2,1,0}), window={size=5x5}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-09-22 09:21:59.399511: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.976773654s
# Trying algorithm eng0{} for conv (f32[32,64,260,388]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,384]{3,2,1,0}, f32[64,64,5,5]{3,2,1,0}), window={size=5x5}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-09-22 09:22:03.694515: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,128,260,388]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,384]{3,2,1,0}, f32[64,128,5,5]{3,2,1,0}), window={size=5x5}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-09-22 09:22:06.662302: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 3.967900089s
# Trying algorithm eng0{} for conv (f32[32,128,260,388]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,384]{3,2,1,0}, f32[64,128,5,5]{3,2,1,0}), window={size=5x5}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-09-22 09:22:26.582496: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,64,260,388]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,128,192]{3,2,1,0}, f32[64,64,5,5]{3,2,1,0}), window={size=5x5 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-09-22 09:22:27.823095: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.240707061s
# Trying algorithm eng0{} for conv (f32[32,64,260,388]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,128,192]{3,2,1,0}, f32[64,64,5,5]{3,2,1,0}), window={size=5x5 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-09-22 09:23:21.228977: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng1{k2=6,k3=0} for conv (f32[64,80,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,80,260,388]{3,2,1,0}, f32[32,64,256,384]{3,2,1,0}), window={size=5x5}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-09-22 09:23:21.391437: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.162583749s
# Trying algorithm eng1{k2=6,k3=0} for conv (f32[64,80,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,80,260,388]{3,2,1,0}, f32[32,64,256,384]{3,2,1,0}), window={size=5x5}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1727011417.287567  111276 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-09-22 09:23:47.294654: W external/local_tsl/tsl/framework/bfc_allocator.cc:482] Allocator (GPU_0_bfc) ran out of memory trying to allocate 28.21GiB (rounded to 30291136768)requested by op
# 2024-09-22 09:23:47.294702: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-09-22 09:23:47.294718: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 103, Chunks in use: 103. 25.8KiB allocated for chunks. 25.8KiB in use in bin. 7.3KiB client-requested in use in bin.
# 2024-09-22 09:23:47.294731: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 13, Chunks in use: 13. 6.8KiB allocated for chunks. 6.8KiB in use in bin. 6.8KiB client-requested in use in bin.
# 2024-09-22 09:23:47.294742: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 25, Chunks in use: 25. 25.8KiB allocated for chunks. 25.8KiB in use in bin. 24.8KiB client-requested in use in bin.
# 2024-09-22 09:23:47.294752: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 1, Chunks in use: 1. 2.5KiB allocated for chunks. 2.5KiB in use in bin. 2.5KiB client-requested in use in bin.
# 2024-09-22 09:23:47.294762: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 4, Chunks in use: 4. 19.8KiB allocated for chunks. 19.8KiB in use in bin. 16.0KiB client-requested in use in bin.
# 2024-09-22 09:23:47.294772: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 2, Chunks in use: 2. 16.0KiB allocated for chunks. 16.0KiB in use in bin. 16.0KiB client-requested in use in bin.
# 2024-09-22 09:23:47.294783: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 6, Chunks in use: 6. 113.5KiB allocated for chunks. 113.5KiB in use in bin. 109.5KiB client-requested in use in bin.
# 2024-09-22 09:23:47.294793: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 3, Chunks in use: 3. 116.0KiB allocated for chunks. 116.0KiB in use in bin. 82.8KiB client-requested in use in bin.
# 2024-09-22 09:23:47.294803: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 16, Chunks in use: 16. 1.12MiB allocated for chunks. 1.12MiB in use in bin. 1.10MiB client-requested in use in bin.
# 2024-09-22 09:23:47.294814: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 6, Chunks in use: 6. 1.09MiB allocated for chunks. 1.09MiB in use in bin. 956.0KiB client-requested in use in bin.
# 2024-09-22 09:23:47.294824: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 15, Chunks in use: 15. 5.40MiB allocated for chunks. 5.40MiB in use in bin. 5.24MiB client-requested in use in bin.
# 2024-09-22 09:23:47.294833: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 7, Chunks in use: 7. 5.43MiB allocated for chunks. 5.43MiB in use in bin. 4.88MiB client-requested in use in bin.
# 2024-09-22 09:23:47.294844: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 11, Chunks in use: 11. 18.36MiB allocated for chunks. 18.36MiB in use in bin. 18.36MiB client-requested in use in bin.
# 2024-09-22 09:23:47.294854: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 4, Chunks in use: 4. 12.50MiB allocated for chunks. 12.50MiB in use in bin. 12.50MiB client-requested in use in bin.
# 2024-09-22 09:23:47.294865: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 16, Chunks in use: 16. 103.91MiB allocated for chunks. 103.91MiB in use in bin. 101.56MiB client-requested in use in bin.
# 2024-09-22 09:23:47.294875: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 1, Chunks in use: 1. 12.00MiB allocated for chunks. 12.00MiB in use in bin. 12.00MiB client-requested in use in bin.
# 2024-09-22 09:23:47.294885: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-22 09:23:47.294896: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 1, Chunks in use: 1. 36.00MiB allocated for chunks. 36.00MiB in use in bin. 36.00MiB client-requested in use in bin.
# 2024-09-22 09:23:47.294910: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-22 09:23:47.294919: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-09-22 09:23:47.294930: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 3, Chunks in use: 2. 45.57GiB allocated for chunks. 20.56GiB in use in bin. 20.56GiB client-requested in use in bin.
# 2024-09-22 09:23:47.294940: I external/local_tsl/tsl/framework/bfc_allocator.cc:1062] Bin for 28.21GiB was 256.00MiB, Chunk State:
# 2024-09-22 09:23:47.294954: I external/local_tsl/tsl/framework/bfc_allocator.cc:1068]   Size: 25.01GiB | Requested Size: 16.06MiB | in_use: 0 | bin_num: 20, prev:   Size: 256B | Requested Size: 4B | in_use: 1 | bin_num: -1
# 2024-09-22 09:23:47.294962: I external/local_tsl/tsl/framework/bfc_allocator.cc:1075] Next region of size 49133387776
# 2024-09-22 09:23:47.294973: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7ec500000000 of size 256 next 1
# 2024-09-22 09:23:47.294981: I external/local_tsl/tsl/framework/bfc_allocator.cc:1095] InUse at 7ec500
: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 8192 totalling 16.0KiB
# 2024-09-22 09:23:47.296307: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 16384 totalling 32.0KiB
# 2024-09-22 09:23:47.296311: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 19200 totalling 37.5KiB
# 2024-09-22 09:23:47.296315: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 20480 totalling 20.0KiB
# 2024-09-22 09:23:47.296319: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 24576 totalling 24.0KiB
# 2024-09-22 09:23:47.296323: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 32768 totalling 64.0KiB
# 2024-09-22 09:23:47.296327: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 53248 totalling 52.0KiB
# 2024-09-22 09:23:47.296331: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 10 Chunks of size 65536 totalling 640.0KiB
# 2024-09-22 09:23:47.296335: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 73728 totalling 72.0KiB
# 2024-09-22 09:23:47.296339: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 81920 totalling 240.0KiB
# 2024-09-22 09:23:47.296343: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 102400 totalling 200.0KiB
# 2024-09-22 09:23:47.296347: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 131072 totalling 128.0KiB
# 2024-09-22 09:23:47.296351: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 196608 totalling 192.0KiB
# 2024-09-22 09:23:47.296355: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 204800 totalling 800.0KiB
# 2024-09-22 09:23:47.296358: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 262144 totalling 768.0KiB
# 2024-09-22 09:23:47.296363: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 327680 totalling 960.0KiB
# 2024-09-22 09:23:47.296366: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 409600 totalling 2.73MiB
# 2024-09-22 09:23:47.296371: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 512000 totalling 1000.0KiB
# 2024-09-22 09:23:47.296375: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 614400 totalling 600.0KiB
# 2024-09-22 09:23:47.296379: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 819200 totalling 3.91MiB
# 2024-09-22 09:23:47.296383: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 983040 totalling 960.0KiB
# 2024-09-22 09:23:47.296387: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 8 Chunks of size 1638400 totalling 12.50MiB
# 2024-09-22 09:23:47.296391: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 2048000 totalling 5.86MiB
# 2024-09-22 09:23:47.296395: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 3276800 totalling 12.50MiB
# 2024-09-22 09:23:47.296398: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 5734400 totalling 5.47MiB
# 2024-09-22 09:23:47.296403: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 12 Chunks of size 6553600 totalling 75.00MiB
# 2024-09-22 09:23:47.296407: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 8192000 totalling 23.44MiB
# 2024-09-22 09:23:47.296411: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 12582912 totalling 12.00MiB
# 2024-09-22 09:23:47.296415: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 37748736 totalling 36.00MiB
# 2024-09-22 09:23:47.296419: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 5518393344 totalling 5.14GiB
# 2024-09-22 09:23:47.296423: I external/local_tsl/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 16555180032 totalling 15.42GiB
# 2024-09-22 09:23:47.296427: I external/local_tsl/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 20.75GiB
# 2024-09-22 09:23:47.296431: I external/local_tsl/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 49133387776 memory_limit_: 49133387776 available bytes: 0 curr_region_allocation_bytes_: 98266775552
# 2024-09-22 09:23:47.296437: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     49133387776
# InUse:                     22279231488
# MaxInUse:                  31780080384
# NumAllocs:                        3764
# MaxAllocSize:              16555180032
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-09-22 09:23:47.296445: W external/local_tsl/tsl/framework/bfc_allocator.cc:494] **********************************************______________________________________________________
# 2024-09-22 09:23:47.296614: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 30291136632 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Now train the model using the shuffled data
# ----> 2 generator.fit(
#       3     X_train,
#       4     Y_train,
#       5     batch_size=32,
#       6     epochs=100,
#       7     callbacks=[early_stopping],
#       8     validation_data=(X_val, Y_val)
#       9 )
#
# File ~/miniconda3/envs/gUstNET/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniconda3/envs/gUstNET/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/runpy.py", line 87, in _run_code
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 701, in start
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/asyncio/events.py", line 80, in _run
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#
#   File "/tmp/ipykernel_110857/3588731260.py", line 2, in <module>
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 320, in fit
#
#   File "/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 121, in one_step_on_iterator
#
# Out of memory while trying to allocate 30291136632 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_one_step_on_iterator_22932]
