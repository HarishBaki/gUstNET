# %%
import xarray as xr
import numpy as np
import zarr
import os, sys, time, glob, re

import tensorflow as tf
print(tf.version)
from tensorflow import keras
print(keras.__version__)

from keras import layers
from keras.layers import Layer
from keras import models, losses
from keras.regularizers import l1,l2
from keras.optimizers import Optimizer
# Set the logging level to suppress warnings
tf.get_logger().setLevel(tf.compat.v1.logging.ERROR)
# Out:
# 2024-09-18 14:08:51.016071: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-18 14:08:51.027407: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-18 14:08:51.030914: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-18 14:08:51.039288: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <module 'tensorflow._api.v2.version' from '/home/harish/miniconda3/envs/gUstNET/lib/python3.9/site-packages/tensorflow/_api/v2/version/__init__.py'>
# 3.5.0

# %%
# Checking if the GPU is available and if it is being used
def run_on_gpu(device_index):
    device_name = f'/device:GPU:{device_index}'
    with tf.device(device_name):
        a = tf.random.uniform([2, 2])
        b = tf.random.uniform([2, 2])
        c = tf.matmul(a, b)
        print(f"Running on {device_name}:")
        print(c.numpy())

# List available GPUs
gpus = tf.config.list_physical_devices('GPU')

# Run the function for each GPU
for i, gpu in enumerate(gpus):
    run_on_gpu(i)
# Out:
# Running on /device:GPU:0:
# [[0.36967012 0.6421738 ]
#  [0.54994255 0.825116  ]]
# Running on /device:GPU:1:
# [[0.2043962  0.04633751]
#  [0.46446294 0.155029  ]]
# Running on /device:GPU:2:
# [[0.01552969 0.14567018]
#  [0.05410055 0.31523645]]

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
gpus = tf.config.experimental.list_physical_devices('GPU')
print(' gpus = ', gpus)
num_gpus = len(gpus)
# Define GPUs
devices = [f'/device:GPU:{i}' for i in range(num_gpus)]

for i, device in enumerate(devices):
    with tf.device(device):
        # Perform training on the assigned GPU
        print(f'Training on device: {device}')
# Out:
# Num GPUs Available:  3
#  gpus =  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')]
# Training on device: /device:GPU:0
# Training on device: /device:GPU:1
# Training on device: /device:GPU:2

# %%
#----------------------------------------------------------------
# Build base U-net architecture
#----------------------------------------------------------------
# Non-linear Activation switch - 0: linear; 1: non-linear
# If non-linear, then Leaky ReLU Activation function with alpha value as input
def actv_swtch(swtch, alpha_val):
    if swtch == 0:
        actv = "linear"
    else:
        actv = layers.LeakyReLU(negative_slope=alpha_val)
    return actv

class ReflectPadding2D(Layer):
    def __init__(self, pad_size, **kwargs):
        self.pad_size = pad_size
        super(ReflectPadding2D, self).__init__(**kwargs)

    def call(self, inputs):
        return tf.pad(inputs, [[0, 0], [self.pad_size, self.pad_size], [self.pad_size, self.pad_size], [0, 0]], mode='REFLECT')

    def get_config(self):
        config = super(ReflectPadding2D, self).get_config()
        config.update({"pad_size": self.pad_size})
        return config
# Defining a generic 3D convolution layer for our use
# Inputs: [input tensor, output feature maps, filter size, dilation rate, stride,
# activation switch, if actv switch is 1 then activation-LReLU-alpha value, 
# regularizer factor]
def con2d(inp, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val):
    # Manually apply reflect padding
    pad_size = fil // 2
    # Use ReflectPadding2D instead of custom padding directly
    inp_padded = ReflectPadding2D(pad_size)(inp)
    # Apply the convolutional layer with 'valid' padding since we've already padded the input
    return layers.Conv2D(n_out, (fil, fil), dilation_rate=(dil_rate, dil_rate),
                                  strides=std,
                                  activation=actv_swtch(swtch, alpha_val),
                                  padding="valid", #padding="same",
                                  use_bias=True,
                                  kernel_regularizer=l2(reg_val),
                                  bias_regularizer=l2(reg_val))(inp_padded)

# Residual convolution block
def Res_conv_block(inp, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val):

    y = con2d(inp, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val)
    y = con2d(y, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val)
    # Residual connection
    y = layers.Add()([y, con2d(inp, n_out, 1, dil_rate, std, swtch, alpha_val, reg_val)])

    return y

# Convolution downsampling block
def Conv_down_block(inp, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val):

    # Downsampling using the stride 2
    y = con2d(inp, n_out, fil, dil_rate, 2, swtch, alpha_val, reg_val)
    y = con2d(y, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val)
    y = con2d(y, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val)

    return y

# Attention block
def Attention(inp, num_heads, key_dim):

    layer = layers.MultiHeadAttention(num_heads, key_dim, attention_axes=None)
    y = layer(inp, inp)

    return y

# Convolution upsampling block using bilinear interpolation
def Conv_up_block(inp, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val):

    # Upsampling using the stride 2 with transpose convolution
    y = layers.UpSampling2D(size=(2, 2), interpolation='bilinear')(inp)
    y = con2d(y, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val)
    y = con2d(y, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val)

    return y

#2D Pooling layer - inputs[0:avg;1:max, input tensor, pool size]
def pool2d(i, inp, ps):
    if i == 0:
        return layers.AveragePooling2D(pool_size=(ps, ps),
                                            strides=None,
                                            padding='same',
                                            data_format=None)(inp)
    else:
        return layers.MaxPooling2D(pool_size=(ps, ps),
                                            strides=None,
                                            padding='same',
                                            data_format=None)(inp)


# Generator architecture
def Gen(inp_lat, inp_lon, out_lat, out_lon, chnl, out_vars, fil, dil_rate, std, swtch, alpha_val, reg_val, num_heads, key_dim):

    inp = layers.Input(shape=(inp_lat, inp_lon, chnl))
    y_st = layers.Input(shape=(out_lat, out_lon, 2))
    y = y_st

    # Encoding path
    skips = []
    for n_out in [64, 128, 256]:
        y = Res_conv_block(y, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val)
        skips.append(Res_conv_block(y, n_out // 4, fil, dil_rate, std, swtch, alpha_val, reg_val))
        y = Conv_down_block(y, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val)

    # Attention block
    y = Res_conv_block(y, 256, fil, dil_rate, std, swtch, alpha_val, reg_val)
    y = Attention(y, num_heads, key_dim)
    y = Res_conv_block(y, 256, fil, dil_rate, std, swtch, alpha_val, reg_val)
    y = Attention(y, num_heads, key_dim)
    y = Res_conv_block(y, 256, fil, dil_rate, std, swtch, alpha_val, reg_val)

    # Decoding path
    for i, n_out in enumerate([256, 128, 64]):
        y = Conv_up_block(y, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val)
        y = layers.Concatenate(axis=-1)([y, skips[-(i + 1)]])
        y = Res_conv_block(y, n_out, fil, dil_rate, std, swtch, alpha_val, reg_val)

    y = Res_conv_block(y, 32, fil, dil_rate, std, swtch, alpha_val, reg_val)

    y = con2d(y, 32, 1, dil_rate, std, 0, 0, reg_val)
    y = con2d(y, out_vars, 1, dil_rate, std, 0, 0, reg_val)

    return models.Model(inputs=[inp, y_st], outputs=y)

# %%
# -------------------------------------------------------------------------
# Model initialising and summary print 
# -------------------------------------------------------------------------
# Build the generator model
x_train = np.random.rand(50,256, 384, 6)
y_train = np.random.rand(50,256, 384, 1)

generator = Gen(x_train.shape[1], x_train.shape[2], y_train.shape[1], y_train.shape[2], 
                  x_train.shape[3], y_train.shape[3], 5, 1, 1, 1, 0.2, 0, 1, 64)
print(generator.summary())
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13      │ (None, 256, 384,  │          0 │ -                 │
# │ (InputLayer)        │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ input_layer_13[0… │
# │ (ReflectPadding2D)  │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_185 (Conv2D) │ (None, 256, 384,  │      3,264 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ conv2d_185[0][0]  │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 256, 384,  │          0 │ input_layer_13[0… │
# │ (ReflectPadding2D)  │ 2)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_186 (Conv2D) │ (None, 256, 384,  │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_187 (Conv2D) │ (None, 256, 384,  │        192 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_43 (Add)        │ (None, 256, 384,  │          0 │ conv2d_186[0][0], │
# │                     │ 64)               │            │ conv2d_187[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ add_43[0][0]      │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_191 (Conv2D) │ (None, 128, 192,  │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ conv2d_191[0][0]  │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_192 (Conv2D) │ (None, 128, 192,  │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ conv2d_192[0][0]  │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_193 (Conv2D) │ (None, 128, 192,  │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ conv2d_193[0][0]  │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_194 (Conv2D) │ (None, 128, 192,  │    204,928 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ conv2d_194[0][0]  │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 128, 192,  │          0 │ conv2d_193[0][0]  │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_195 (Conv2D) │ (None, 128, 192,  │    409,728 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_196 (Conv2D) │ (None, 128, 192,  │      8,320 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_45 (Add)        │ (None, 128, 192,  │          0 │ conv2d_195[0][0], │
# │                     │ 128)              │            │ conv2d_196[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ add_45[0][0]      │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_200 (Conv2D) │ (None, 64, 96,    │    409,728 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_200[0][0]  │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_201 (Conv2D) │ (None, 64, 96,    │    409,728 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_201[0][0]  │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_202 (Conv2D) │ (None, 64, 96,    │    409,728 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_202[0][0]  │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_203 (Conv2D) │ (None, 64, 96,    │    819,456 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_203[0][0]  │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 64, 96,    │          0 │ conv2d_202[0][0]  │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_204 (Conv2D) │ (None, 64, 96,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_205 (Conv2D) │ (None, 64, 96,    │     33,024 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_47 (Add)        │ (None, 64, 96,    │          0 │ conv2d_204[0][0], │
# │                     │ 256)              │            │ conv2d_205[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ add_47[0][0]      │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_209 (Conv2D) │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ conv2d_209[0][0]  │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_210 (Conv2D) │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ conv2d_210[0][0]  │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_211 (Conv2D) │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ conv2d_211[0][0]  │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_212 (Conv2D) │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ conv2d_212[0][0]  │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 32, 48,    │          0 │ conv2d_211[0][0]  │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_213 (Conv2D) │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_214 (Conv2D) │ (None, 32, 48,    │     65,792 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_49 (Add)        │ (None, 32, 48,    │          0 │ conv2d_213[0][0], │
# │                     │ 256)              │            │ conv2d_214[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 32, 48,    │     65,984 │ add_49[0][0],     │
# │ (MultiHeadAttentio… │ 256)              │            │ add_49[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ multi_head_atten… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_215 (Conv2D) │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ conv2d_215[0][0]  │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 32, 48,    │          0 │ multi_head_atten… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_216 (Conv2D) │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_217 (Conv2D) │ (None, 32, 48,    │     65,792 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_50 (Add)        │ (None, 32, 48,    │          0 │ conv2d_216[0][0], │
# │                     │ 256)              │            │ conv2d_217[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 32, 48,    │     65,984 │ add_50[0][0],     │
# │ (MultiHeadAttentio… │ 256)              │            │ add_50[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ multi_head_atten… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_218 (Conv2D) │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 36, 52,    │          0 │ conv2d_218[0][0]  │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 32, 48,    │          0 │ multi_head_atten… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_219 (Conv2D) │ (None, 32, 48,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_220 (Conv2D) │ (None, 32, 48,    │     65,792 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_51 (Add)        │ (None, 32, 48,    │          0 │ conv2d_219[0][0], │
# │                     │ 256)              │            │ conv2d_220[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 64, 96,    │          0 │ add_51[0][0]      │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ add_47[0][0]      │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ up_sampling2d_9[… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_206 (Conv2D) │ (None, 64, 96,    │    409,664 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_221 (Conv2D) │ (None, 64, 96,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_206[0][0]  │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 64, 96,    │          0 │ add_47[0][0]      │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_221[0][0]  │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_207 (Conv2D) │ (None, 64, 96,    │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_208 (Conv2D) │ (None, 64, 96,    │     16,448 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_222 (Conv2D) │ (None, 64, 96,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_48 (Add)        │ (None, 64, 96,    │          0 │ conv2d_207[0][0], │
# │                     │ 64)               │            │ conv2d_208[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 64, 96,    │          0 │ conv2d_222[0][0], │
# │ (Concatenate)       │ 320)              │            │ add_48[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ concatenate_9[0]… │
# │ (ReflectPadding2D)  │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_223 (Conv2D) │ (None, 64, 96,    │  2,048,256 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 68, 100,   │          0 │ conv2d_223[0][0]  │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 64, 96,    │          0 │ concatenate_9[0]… │
# │ (ReflectPadding2D)  │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_224 (Conv2D) │ (None, 64, 96,    │  1,638,656 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_225 (Conv2D) │ (None, 64, 96,    │     82,176 │ reflect_padding2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_52 (Add)        │ (None, 64, 96,    │          0 │ conv2d_224[0][0], │
# │                     │ 256)              │            │ conv2d_225[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_10    │ (None, 128, 192,  │          0 │ add_52[0][0]      │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ add_45[0][0]      │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ up_sampling2d_10… │
# │ (ReflectPadding2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_197 (Conv2D) │ (None, 128, 192,  │    102,432 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_226 (Conv2D) │ (None, 128, 192,  │    819,328 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ conv2d_197[0][0]  │
# │ (ReflectPadding2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 128, 192,  │          0 │ add_45[0][0]      │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ conv2d_226[0][0]  │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_198 (Conv2D) │ (None, 128, 192,  │     25,632 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_199 (Conv2D) │ (None, 128, 192,  │      4,128 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_227 (Conv2D) │ (None, 128, 192,  │    409,728 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_46 (Add)        │ (None, 128, 192,  │          0 │ conv2d_198[0][0], │
# │                     │ 32)               │            │ conv2d_199[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 128, 192,  │          0 │ conv2d_227[0][0], │
# │ (Concatenate)       │ 160)              │            │ add_46[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ concatenate_10[0… │
# │ (ReflectPadding2D)  │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_228 (Conv2D) │ (None, 128, 192,  │    512,128 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 132, 196,  │          0 │ conv2d_228[0][0]  │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 128, 192,  │          0 │ concatenate_10[0… │
# │ (ReflectPadding2D)  │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_229 (Conv2D) │ (None, 128, 192,  │    409,728 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_230 (Conv2D) │ (None, 128, 192,  │     20,608 │ reflect_padding2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_53 (Add)        │ (None, 128, 192,  │          0 │ conv2d_229[0][0], │
# │                     │ 128)              │            │ conv2d_230[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_11    │ (None, 256, 384,  │          0 │ add_53[0][0]      │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ add_43[0][0]      │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ up_sampling2d_11… │
# │ (ReflectPadding2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_188 (Conv2D) │ (None, 256, 384,  │     25,616 │ reflect_padding2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_231 (Conv2D) │ (None, 256, 384,  │    204,864 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ conv2d_188[0][0]  │
# │ (ReflectPadding2D)  │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 256, 384,  │          0 │ add_43[0][0]      │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ conv2d_231[0][0]  │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_189 (Conv2D) │ (None, 256, 384,  │      6,416 │ reflect_padding2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_190 (Conv2D) │ (None, 256, 384,  │      1,040 │ reflect_padding2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_232 (Conv2D) │ (None, 256, 384,  │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_44 (Add)        │ (None, 256, 384,  │          0 │ conv2d_189[0][0], │
# │                     │ 16)               │            │ conv2d_190[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 256, 384,  │          0 │ conv2d_232[0][0], │
# │ (Concatenate)       │ 80)               │            │ add_44[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ concatenate_11[0… │
# │ (ReflectPadding2D)  │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_233 (Conv2D) │ (None, 256, 384,  │    128,064 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ conv2d_233[0][0]  │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 256, 384,  │          0 │ concatenate_11[0… │
# │ (ReflectPadding2D)  │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_234 (Conv2D) │ (None, 256, 384,  │    102,464 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_235 (Conv2D) │ (None, 256, 384,  │      5,184 │ reflect_padding2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_54 (Add)        │ (None, 256, 384,  │          0 │ conv2d_234[0][0], │
# │                     │ 64)               │            │ conv2d_235[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ add_54[0][0]      │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_236 (Conv2D) │ (None, 256, 384,  │     51,232 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 260, 388,  │          0 │ conv2d_236[0][0]  │
# │ (ReflectPadding2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 256, 384,  │          0 │ add_54[0][0]      │
# │ (ReflectPadding2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_237 (Conv2D) │ (None, 256, 384,  │     25,632 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_238 (Conv2D) │ (None, 256, 384,  │      2,080 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_55 (Add)        │ (None, 256, 384,  │          0 │ conv2d_237[0][0], │
# │                     │ 32)               │            │ conv2d_238[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 256, 384,  │          0 │ add_55[0][0]      │
# │ (ReflectPadding2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_239 (Conv2D) │ (None, 256, 384,  │      1,056 │ reflect_padding2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reflect_padding2d_… │ (None, 256, 384,  │          0 │ conv2d_239[0][0]  │
# │ (ReflectPadding2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_12      │ (None, 256, 384,  │          0 │ -                 │
# │ (InputLayer)        │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_240 (Conv2D) │ (None, 256, 384,  │         33 │ reflect_padding2… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,368,689 (115.85 MB)
#  Trainable params: 30,368,689 (115.85 MB)
#  Non-trainable params: 0 (0.00 B)
# None
